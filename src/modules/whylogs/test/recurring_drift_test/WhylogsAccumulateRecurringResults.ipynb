# %%
import pandas as pd

# %%
data = {
    "100": ["{}".format(-99) for i in range(1,21,1)],
    "95" : ["{}".format(-99) for i in range(1,21,1)],
    "90" : ["{}".format(-99) for i in range(1,21,1)],
    "85" : ["{}".format(-99) for i in range(1,21,1)],
    "80" : ["{}".format(-99) for i in range(1,21,1)],
    "75" : ["{}".format(-99) for i in range(1,21,1)],
    "70" : ["{}".format(-99) for i in range(1,21,1)],
    "65" : ["{}".format(-99) for i in range(1,21,1)],
    "60" : ["{}".format(-99) for i in range(1,21,1)],
    "55" : ["{}".format(-99) for i in range(1,21,1)],
    "50" : ["{}".format(-99) for i in range(1,21,1)],
    "45" : ["{}".format(-99) for i in range(1,21,1)],
    "40" : ["{}".format(-99) for i in range(1,21,1)],
    "35" : ["{}".format(-99) for i in range(1,21,1)],
    "30" : ["{}".format(-99) for i in range(1,21,1)],
    "25" : ["{}".format(-99) for i in range(1,21,1)],
    "20" : ["{}".format(-99) for i in range(1,21,1)],
    "15" : ["{}".format(-99) for i in range(1,21,1)],
    "10" : ["{}".format(-99) for i in range(1,21,1)],
    "5" :  ["{}".format(-99) for i in range(1,21,1)],
}
df_new = pd.DataFrame(data,index=["{}".format(i) for i in range(1,21,1)])
df_new
# Out:
#     100   95   90   85   80   75   70   65   60   55   50   45   40   35   30  \
# 1   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 2   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 3   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 4   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 5   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 6   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 7   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 8   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 9   -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 10  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 11  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 12  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 13  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 14  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 15  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 16  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 17  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 18  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 19  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
# 20  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99  -99
#
#      25   20   15   10    5
# 1   -99  -99  -99  -99  -99
# 2   -99  -99  -99  -99  -99
# 3   -99  -99  -99  -99  -99
# 4   -99  -99  -99  -99  -99
# 5   -99  -99  -99  -99  -99
# 6   -99  -99  -99  -99  -99
# 7   -99  -99  -99  -99  -99
# 8   -99  -99  -99  -99  -99
# 9   -99  -99  -99  -99  -99
# 10  -99  -99  -99  -99  -99
# 11  -99  -99  -99  -99  -99
# 12  -99  -99  -99  -99  -99
# 13  -99  -99  -99  -99  -99
# 14  -99  -99  -99  -99  -99
# 15  -99  -99  -99  -99  -99
# 16  -99  -99  -99  -99  -99
# 17  -99  -99  -99  -99  -99
# 18  -99  -99  -99  -99  -99
# 19  -99  -99  -99  -99  -99
# 20  -99  -99  -99  -99  -99

# %% [markdown]
# RXRX1 Results

# %%
for i in range(5,105,5):
    for j in range(1,21,1):
        df = pd.read_csv('/home/ubuntu/image-drift-monitoring/data/rxrx1_v1.0/drifted_data/recurring_drift/whylogs_output/profile_compare/rxrx1_{}_v_{}.csv'.format(i,j),delimiter=',',index_col=[0])
        res = []
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Brightness.mean':
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Brightness.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Hue.mean':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Hue.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Saturation.mean':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Saturation.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        # testing for viz
        accum = 0
        for r in res :
            accum = accum + r
        df_new.loc['{}'.format(j)]['{}'.format(i)] = accum / 6


df_new.to_excel('rxrx1_whylogs_results_recurring.xlsx')

# %% [markdown]
# iWILDCAM Results

# %%
for i in range(5,105,5):
    for j in range(1,21,1):
        df = pd.read_csv('/home/ubuntu/image-drift-monitoring/data/iwildcam_v2.0/drifted_data/recurring_drift/whylogs_output/profile_compare/iwildcam_{}_v_{}.csv'.format(i,j),delimiter=',',index_col=[0])
        res = []
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Brightness.mean':
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Brightness.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Hue.mean':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Hue.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Saturation.mean':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Saturation.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        # testing for viz
        accum = 0
        for r in res :
            accum = accum + r
        df_new.loc['{}'.format(j)]['{}'.format(i)] = accum / 6


df_new.to_excel('iwildcam_whylogs_results_recurring.xlsx')

# %% [markdown]
# GlobalWheat Results

# %%
for i in range(5,105,5):
    for j in range(1,21,1):
        df = pd.read_csv('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/drifted_data/recurring_drift/whylogs_output/profile_compare/globalwheat_{}_v_{}.csv'.format(i,j),delimiter=',',index_col=[0])
        res = []
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Brightness.mean':
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Brightness.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Hue.mean':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Hue.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Saturation.mean':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Saturation.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)

         # testing for viz
        accum = 0
        for r in res :
            accum = accum + r
        df_new.loc['{}'.format(j)]['{}'.format(i)] = accum /6


df_new.to_excel('globalwheat_whylogs_results_recurring.xlsx')

# %% [markdown]
# Camelyon Results

# %%
for i in range(5,105,5):
    for j in range(1,21,1):
        df = pd.read_csv('/home/ubuntu/image-drift-monitoring/data/camelyon17_v1.0/drifted_data/recurring_drift/whylogs_output/profile_compare/camelyon_{}_v_{}.csv'.format(i,j),delimiter=',',index_col=[0])
        res = []
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Brightness.mean':
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Brightness.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Hue.mean':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Hue.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Saturation.mean':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
        for n in range(0,8,1):
            if df.loc[n]['metric'] == 'image.Saturation.stddev':                 
                if df.loc[n]['rating'] == 'Possible Drift (0.05 - 0.15)': res.append(0.15)
                if df.loc[n]['rating'] == 'Detected Drift (0.00 - 0.05)': res.append(1)
                if df.loc[n]['rating'] == 'No Drift (0.15 - 1.00)': res.append(0)
         # testing for viz
        accum = 0
        for r in res :
            accum = accum + r
        df_new.loc['{}'.format(j)]['{}'.format(i)] = accum /6



df_new.to_excel('camelyon_whylogs_results_recurring.xlsx')
