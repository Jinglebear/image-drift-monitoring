# %%
import numpy as np
# %cd  '/home/ubuntu/image-drift-monitoring/data/camelyon17_v1.0'
# %pwd
camelyon_train_comp = np.load('camelyon_train_ds.npz')

# %%
camelyon_train = camelyon_train_comp['arr_0']

np.random.shuffle(camelyon_train)

# %%
camelyon_train_0_50 = camelyon_train[:int(len(camelyon_train)/2)]
camelyon_train_50_100 = camelyon_train[:int(len(camelyon_train)/2)]

# %%
camelyon_train_0_25   = camelyon_train[:int(len(camelyon_train)/4)]
camelyon_train_0_12_5  = camelyon_train_0_25[:int(len(camelyon_train_0_25)/2)]
camelyon_train_12_5_25 = camelyon_train_0_25[int(len(camelyon_train_0_25)/2):]

# %%
import torch
camelyon_train_0_12_5 = torch.as_tensor(camelyon_train_0_12_5)

# %%
# %cd  '/home/ubuntu/image-drift-monitoring'
# %pwd
from src.modules.alibi_detect.trained_autoencoder import TrainedAutoencoder

myTAE = TrainedAutoencoder()
from torch.utils.data import TensorDataset, DataLoader
camelyon_train_0_12_5_dl = DataLoader(TensorDataset(camelyon_train_0_12_5,camelyon_train_0_12_5),32,shuffle=True)

# %%
myTAE.init_default_pt_autoencoder(camelyon_train_0_12_5_dl)

# %% [markdown]
# # CAMELYON

# %% [markdown]
# KS init TAE

# %%
# %cd  '/home/ubuntu/image-drift-monitoring'
# %pwd
import numpy as np
from src.modules.alibi_detect.trained_autoencoder import TrainedAutoencoder
from torch.utils.data import TensorDataset, DataLoader
import json 
import torch


with open('/home/ubuntu/image-drift-monitoring/config/common/drift_detection_config.json') as config_file:
        drift_detection_config = json.load(config_file)



camelyon_train_5_comp = np.load('/home/ubuntu/image-drift-monitoring/data/camelyon17_v1.0/camelyon_train_5_ds.npz')
camelyon_train_5 = camelyon_train_5_comp['arr_0']
camelyon_train_5_0_50 = camelyon_train_5[:int(len(camelyon_train_5)*0.5)]
camelyon_train_5_50_100 = camelyon_train_5[int(len(camelyon_train_5)*0.5):]



camelyon_train_5_0_50 = torch.as_tensor(camelyon_train_5_0_50)
camelyon_train_5_0_50_dl = DataLoader(TensorDataset(camelyon_train_5_0_50,camelyon_train_5_0_50),drift_detection_config['TAE']['BATCH_SIZE'],shuffle=True)

myTAE = TrainedAutoencoder(drift_detection_config)
myTAE.init_default_pt_autoencoder(camelyon_train_5_0_50_dl)
myTAE.init_detector(detector_type='KS',reference_data=camelyon_train_5_50_100,detector_name='camelyon_TAE_5_KS',save_dec=True)

# globalwheat_train_5_comp = None
# globalwheat_train_5 = None
# camelyon_train_5_0_50 = None 
# camelyon_train_5_50_100 = None
# globalwheat_train_5_dl = None
# myTAE = None

# %% [markdown]
# CVM init TAE

# %%
# %cd  '/home/ubuntu/image-drift-monitoring'
# %pwd
import numpy as np
from src.modules.alibi_detect.untrained_encoder import UntrainedAutoencoder
import json 



with open('/home/ubuntu/image-drift-monitoring/config/common/drift_detection_config.json') as config_file:
        drift_detection_config = json.load(config_file)


globalwheat_train_5_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_5_ds.npz')
globalwheat_train_5 = globalwheat_train_5_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_5.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_5,detector_name='globalwheat_TAE_5_CVM',save_dec=True)

globalwheat_train_5_comp = None
globalwheat_train_5 = None
myTAE = None


globalwheat_train_10_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_10_ds.npz')
globalwheat_train_10 = globalwheat_train_10_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_10.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_10,detector_name='globalwheat_TAE_10_CVM',save_dec=True)

globalwheat_train_10_comp = None
globalwheat_train_10 = None
myTAE = None

globalwheat_train_15_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_15_ds.npz')
globalwheat_train_15 = globalwheat_train_15_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_15.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_15,detector_name='globalwheat_TAE_15_CVM',save_dec=True)

globalwheat_train_15_comp = None
globalwheat_train_15 = None
myTAE = None

globalwheat_train_20_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_20_ds.npz')
globalwheat_train_20 = globalwheat_train_20_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_20.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_20,detector_name='globalwheat_TAE_20_CVM',save_dec=True)

globalwheat_train_20_comp = None
globalwheat_train_20 = None
myTAE = None

globalwheat_train_25_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_25_ds.npz')
globalwheat_train_25 = globalwheat_train_25_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_25.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_25,detector_name='globalwheat_TAE_25_CVM',save_dec=True)

globalwheat_train_25_comp = None
globalwheat_train_25 = None
myTAE = None

globalwheat_train_30_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_30_ds.npz')
globalwheat_train_30 = globalwheat_train_30_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_30.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_30,detector_name='globalwheat_TAE_30_CVM',save_dec=True)

globalwheat_train_30_comp = None
globalwheat_train_30 = None
myTAE = None

globalwheat_train_35_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_35_ds.npz')
globalwheat_train_35 = globalwheat_train_35_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_35.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_35,detector_name='globalwheat_TAE_35_CVM',save_dec=True)

globalwheat_train_35_comp = None
globalwheat_train_35 = None
myTAE = None

globalwheat_train_40_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_40_ds.npz')
globalwheat_train_40 = globalwheat_train_40_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_40.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_40,detector_name='globalwheat_TAE_40_CVM',save_dec=True)

globalwheat_train_40_comp = None
globalwheat_train_40 = None
myTAE = None

globalwheat_train_45_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_45_ds.npz')
globalwheat_train_45 = globalwheat_train_45_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_45.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_45,detector_name='globalwheat_TAE_45_CVM',save_dec=True)

globalwheat_train_45_comp = None
globalwheat_train_45 = None
myTAE = None

globalwheat_train_50_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_50_ds.npz')
globalwheat_train_50 = globalwheat_train_50_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_50.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_50,detector_name='globalwheat_TAE_50_CVM',save_dec=True)

globalwheat_train_50_comp = None
globalwheat_train_50 = None
myTAE = None

globalwheat_train_55_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_55_ds.npz')
globalwheat_train_55 = globalwheat_train_55_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_55.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_55,detector_name='globalwheat_TAE_55_CVM',save_dec=True)

globalwheat_train_55_comp = None
globalwheat_train_55 = None
myTAE = None


globalwheat_train_60_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_60_ds.npz')
globalwheat_train_60 = globalwheat_train_60_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_60.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_60,detector_name='globalwheat_TAE_60_CVM',save_dec=True)

globalwheat_train_60_comp = None
globalwheat_train_60 = None
myTAE = None

globalwheat_train_65_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_65_ds.npz')
globalwheat_train_65 = globalwheat_train_65_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_65.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_65,detector_name='globalwheat_TAE_65_CVM',save_dec=True)

globalwheat_train_65_comp = None
globalwheat_train_65 = None
myTAE = None

globalwheat_train_70_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_70_ds.npz')
globalwheat_train_70 = globalwheat_train_70_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_70.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_70,detector_name='globalwheat_TAE_70_CVM',save_dec=True)

globalwheat_train_70_comp = None
globalwheat_train_70 = None
myTAE = None

globalwheat_train_75_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_75_ds.npz')
globalwheat_train_75 = globalwheat_train_75_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_75.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_75,detector_name='globalwheat_TAE_75_CVM',save_dec=True)

globalwheat_train_75_comp = None
globalwheat_train_75 = None
myTAE = None

globalwheat_train_80_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_80_ds.npz')
globalwheat_train_80 = globalwheat_train_80_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_80.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_80,detector_name='globalwheat_TAE_80_CVM',save_dec=True)

globalwheat_train_80_comp = None
globalwheat_train_80 = None
myTAE = None

globalwheat_train_85_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_85_ds.npz')
globalwheat_train_85 = globalwheat_train_85_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_85.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_85,detector_name='globalwheat_TAE_85_CVM',save_dec=True)

globalwheat_train_85_comp = None
globalwheat_train_85 = None
myTAE = None

globalwheat_train_90_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_90_ds.npz')
globalwheat_train_90 = globalwheat_train_90_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_90.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_90,detector_name='globalwheat_TAE_90_CVM',save_dec=True)

globalwheat_train_90_comp = None
globalwheat_train_90 = None
myTAE = None

globalwheat_train_95_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_95_ds.npz')
globalwheat_train_95 = globalwheat_train_95_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_95.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_95,detector_name='globalwheat_TAE_95_CVM',save_dec=True)

globalwheat_train_95_comp = None
globalwheat_train_95 = None
myTAE = None

globalwheat_train_100_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_ds.npz')
globalwheat_train_100 = globalwheat_train_100_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_100.shape[1:])
myTAE.init_detector(detector_type='CVM',reference_data=globalwheat_train_100,detector_name='globalwheat_TAE_100_CVM',save_dec=True)

globalwheat_train_100_comp = None
globalwheat_train_100 = None
myTAE = None

# %% [markdown]
# MMD init TAE

# %%
# %cd  '/home/ubuntu/image-drift-monitoring'
# %pwd
import numpy as np
from src.modules.alibi_detect.untrained_encoder import UntrainedAutoencoder
import json 
import os


with open('/home/ubuntu/image-drift-monitoring/config/common/drift_detection_config.json') as config_file:
        drift_detection_config = json.load(config_file)

# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
globalwheat_train_5_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_5_ds.npz')
globalwheat_train_5 = globalwheat_train_5_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_5.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_5,detector_name='globalwheat_TAE_5_MMD',save_dec=True)

globalwheat_train_5_comp = None
globalwheat_train_5 = None
myTAE = None


globalwheat_train_10_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_10_ds.npz')
globalwheat_train_10 = globalwheat_train_10_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_10.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_10,detector_name='globalwheat_TAE_10_MMD',save_dec=True)

globalwheat_train_10_comp = None

myTAE = None

globalwheat_train_15_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_15_ds.npz')
globalwheat_train_15 = globalwheat_train_15_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_10.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_15,detector_name='globalwheat_TAE_15_MMD',save_dec=True)

globalwheat_train_15_comp = None
globalwheat_train_15 = None
myTAE = None

globalwheat_train_20_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_20_ds.npz')
globalwheat_train_20 = globalwheat_train_20_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_20.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_20,detector_name='globalwheat_TAE_20_MMD',save_dec=True)

globalwheat_train_20_comp = None
globalwheat_train_20 = None
myTAE = None

globalwheat_train_25_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_25_ds.npz')
globalwheat_train_25 = globalwheat_train_25_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_25.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_25,detector_name='globalwheat_TAE_25_MMD',save_dec=True)

globalwheat_train_25_comp = None
globalwheat_train_25 = None
myTAE = None

globalwheat_train_30_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_30_ds.npz')
globalwheat_train_30 = globalwheat_train_30_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_30.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_30,detector_name='globalwheat_TAE_30_MMD',save_dec=True)

globalwheat_train_30_comp = None
globalwheat_train_30 = None
myTAE = None

globalwheat_train_35_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_35_ds.npz')
globalwheat_train_35 = globalwheat_train_35_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_35.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_35,detector_name='globalwheat_TAE_35_MMD',save_dec=True)

globalwheat_train_35_comp = None
globalwheat_train_35 = None
myTAE = None

globalwheat_train_40_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_40_ds.npz')
globalwheat_train_40 = globalwheat_train_40_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_40.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_40,detector_name='globalwheat_TAE_40_MMD',save_dec=True)

globalwheat_train_40_comp = None
globalwheat_train_40 = None
myTAE = None

globalwheat_train_45_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_45_ds.npz')
globalwheat_train_45 = globalwheat_train_45_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_45.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_45,detector_name='globalwheat_TAE_45_MMD',save_dec=True)

globalwheat_train_45_comp = None
globalwheat_train_45 = None
myTAE = None

globalwheat_train_50_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_50_ds.npz')
globalwheat_train_50 = globalwheat_train_50_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_50.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_50,detector_name='globalwheat_TAE_50_MMD',save_dec=True)

globalwheat_train_50_comp = None
globalwheat_train_50 = None
myTAE = None

globalwheat_train_55_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_55_ds.npz')
globalwheat_train_55 = globalwheat_train_55_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_55.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_55,detector_name='globalwheat_TAE_55_MMD',save_dec=True)

globalwheat_train_55_comp = None
globalwheat_train_55 = None
myTAE = None


globalwheat_train_60_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_60_ds.npz')
globalwheat_train_60 = globalwheat_train_60_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_60.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_60,detector_name='globalwheat_TAE_60_MMD',save_dec=True)

globalwheat_train_60_comp = None
globalwheat_train_60 = None
myTAE = None

globalwheat_train_65_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_65_ds.npz')
globalwheat_train_65 = globalwheat_train_65_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_65.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_65,detector_name='globalwheat_TAE_65_MMD',save_dec=True)

globalwheat_train_65_comp = None
globalwheat_train_65 = None
myTAE = None

globalwheat_train_70_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_70_ds.npz')
globalwheat_train_70 = globalwheat_train_70_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_70.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_70,detector_name='globalwheat_TAE_70_MMD',save_dec=True)

globalwheat_train_70_comp = None
globalwheat_train_70 = None
myTAE = None

globalwheat_train_75_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_75_ds.npz')
globalwheat_train_75 = globalwheat_train_75_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_75.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_75,detector_name='globalwheat_TAE_75_MMD',save_dec=True)

globalwheat_train_75_comp = None
globalwheat_train_75 = None
myTAE = None

globalwheat_train_80_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_80_ds.npz')
globalwheat_train_80 = globalwheat_train_80_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_80.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_80,detector_name='globalwheat_TAE_80_MMD',save_dec=True)

globalwheat_train_80_comp = None
globalwheat_train_80 = None
myTAE = None

globalwheat_train_85_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_85_ds.npz')
globalwheat_train_85 = globalwheat_train_85_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_85.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_85,detector_name='globalwheat_TAE_85_MMD',save_dec=True)

globalwheat_train_85_comp = None
globalwheat_train_85 = None
myTAE = None

globalwheat_train_90_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_90_ds.npz')
globalwheat_train_90 = globalwheat_train_90_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_90.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_90,detector_name='globalwheat_TAE_90_MMD',save_dec=True)

globalwheat_train_90_comp = None
globalwheat_train_90 = None
myTAE = None

globalwheat_train_95_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_95_ds.npz')
globalwheat_train_95 = globalwheat_train_95_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_95.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_95,detector_name='globalwheat_TAE_95_MMD',save_dec=True)

globalwheat_train_95_comp = None
globalwheat_train_95 = None
myTAE = None

globalwheat_train_100_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_ds.npz')
globalwheat_train_100 = globalwheat_train_100_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_100.shape[1:])
myTAE.init_detector(detector_type='MMD',reference_data=globalwheat_train_100,detector_name='globalwheat_TAE_100_MMD',save_dec=True)

globalwheat_train_100_comp = None
globalwheat_train_100 = None
myTAE = None

# %% [markdown]
# LSDD init TAE

# %%
# %cd  '/home/ubuntu/image-drift-monitoring'
# %pwd
import numpy as np
from src.modules.alibi_detect.untrained_encoder import UntrainedAutoencoder
import json 



with open('/home/ubuntu/image-drift-monitoring/config/common/drift_detection_config.json') as config_file:
        drift_detection_config = json.load(config_file)


globalwheat_train_5_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_5_ds.npz')
globalwheat_train_5 = globalwheat_train_5_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_5.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_5,detector_name='globalwheat_TAE_5_LSDD',save_dec=True)

globalwheat_train_5_comp = None
globalwheat_train_5 = None
myTAE = None


globalwheat_train_10_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_10_ds.npz')
globalwheat_train_10 = globalwheat_train_10_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_10.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_10,detector_name='globalwheat_TAE_10_LSDD',save_dec=True)

globalwheat_train_10_comp = None
globalwheat_train_10 = None
myTAE = None

globalwheat_train_15_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_15_ds.npz')
globalwheat_train_15 = globalwheat_train_15_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_15.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_15,detector_name='globalwheat_TAE_15_LSDD',save_dec=True)

globalwheat_train_15_comp = None
globalwheat_train_15 = None
myTAE = None

globalwheat_train_20_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_20_ds.npz')
globalwheat_train_20 = globalwheat_train_20_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_20.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_20,detector_name='globalwheat_TAE_20_LSDD',save_dec=True)

globalwheat_train_20_comp = None
globalwheat_train_20 = None
myTAE = None

globalwheat_train_25_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_25_ds.npz')
globalwheat_train_25 = globalwheat_train_25_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_25.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_25,detector_name='globalwheat_TAE_25_LSDD',save_dec=True)

globalwheat_train_25_comp = None
globalwheat_train_25 = None
myTAE = None

globalwheat_train_30_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_30_ds.npz')
globalwheat_train_30 = globalwheat_train_30_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_30.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_30,detector_name='globalwheat_TAE_30_LSDD',save_dec=True)

globalwheat_train_30_comp = None
globalwheat_train_30 = None
myTAE = None

globalwheat_train_35_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_35_ds.npz')
globalwheat_train_35 = globalwheat_train_35_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_35.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_35,detector_name='globalwheat_TAE_35_LSDD',save_dec=True)

globalwheat_train_35_comp = None
globalwheat_train_35 = None
myTAE = None

globalwheat_train_40_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_40_ds.npz')
globalwheat_train_40 = globalwheat_train_40_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_40.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_40,detector_name='globalwheat_TAE_40_LSDD',save_dec=True)

globalwheat_train_40_comp = None
globalwheat_train_40 = None
myTAE = None

globalwheat_train_45_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_45_ds.npz')
globalwheat_train_45 = globalwheat_train_45_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_45.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_45,detector_name='globalwheat_TAE_45_LSDD',save_dec=True)

globalwheat_train_45_comp = None
globalwheat_train_45 = None
myTAE = None

globalwheat_train_50_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_50_ds.npz')
globalwheat_train_50 = globalwheat_train_50_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_50.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_50,detector_name='globalwheat_TAE_50_LSDD',save_dec=True)

globalwheat_train_50_comp = None
globalwheat_train_50 = None
myTAE = None

globalwheat_train_55_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_55_ds.npz')
globalwheat_train_55 = globalwheat_train_55_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_55.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_55,detector_name='globalwheat_TAE_55_LSDD',save_dec=True)

globalwheat_train_55_comp = None
globalwheat_train_55 = None
myTAE = None


globalwheat_train_60_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_60_ds.npz')
globalwheat_train_60 = globalwheat_train_60_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_60.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_60,detector_name='globalwheat_TAE_60_LSDD',save_dec=True)

globalwheat_train_60_comp = None
globalwheat_train_60 = None
myTAE = None

globalwheat_train_65_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_65_ds.npz')
globalwheat_train_65 = globalwheat_train_65_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_65.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_65,detector_name='globalwheat_TAE_65_LSDD',save_dec=True)

globalwheat_train_65_comp = None
globalwheat_train_65 = None
myTAE = None

globalwheat_train_70_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_70_ds.npz')
globalwheat_train_70 = globalwheat_train_70_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_70.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_70,detector_name='globalwheat_TAE_70_LSDD',save_dec=True)

globalwheat_train_70_comp = None
globalwheat_train_70 = None
myTAE = None

globalwheat_train_75_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_75_ds.npz')
globalwheat_train_75 = globalwheat_train_75_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_75.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_75,detector_name='globalwheat_TAE_75_LSDD',save_dec=True)

globalwheat_train_75_comp = None
globalwheat_train_75 = None
myTAE = None

globalwheat_train_80_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_80_ds.npz')
globalwheat_train_80 = globalwheat_train_80_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_80.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_80,detector_name='globalwheat_TAE_80_LSDD',save_dec=True)

globalwheat_train_80_comp = None
globalwheat_train_80 = None
myTAE = None

globalwheat_train_85_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_85_ds.npz')
globalwheat_train_85 = globalwheat_train_85_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_85.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_85,detector_name='globalwheat_TAE_85_LSDD',save_dec=True)

globalwheat_train_85_comp = None
globalwheat_train_85 = None
myTAE = None

globalwheat_train_90_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_90_ds.npz')
globalwheat_train_90 = globalwheat_train_90_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_90.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_90,detector_name='globalwheat_TAE_90_LSDD',save_dec=True)

globalwheat_train_90_comp = None
globalwheat_train_90 = None
myTAE = None

globalwheat_train_95_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_95_ds.npz')
globalwheat_train_95 = globalwheat_train_95_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_95.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_95,detector_name='globalwheat_TAE_95_LSDD',save_dec=True)

globalwheat_train_95_comp = None
globalwheat_train_95 = None
myTAE = None

globalwheat_train_100_comp = np.load('/home/ubuntu/image-drift-monitoring/data/globalwheat_v1.1/globalwheat_train_ds.npz')
globalwheat_train_100 = globalwheat_train_100_comp['arr_0']

myTAE = UntrainedAutoencoder(drift_detection_config)
myTAE.init_default_tf_encoder(encoding_dim=96,input_shape=globalwheat_train_100.shape[1:])
myTAE.init_detector(detector_type='LSDD',reference_data=globalwheat_train_100,detector_name='globalwheat_TAE_100_MMD_LSDD',save_dec=True)

globalwheat_train_100_comp = None
globalwheat_train_100 = None
myTAE = None
